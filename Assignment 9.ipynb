# %% [markdown]
# #### Familiarizing with Pandas library
#
# * Read the dataset into a pandas dataframe and explore various pandas functions over that data.
# * Majorly focus on
#     * Multi-indexing
#     * Concat and Append
#     * Merge and Joins

# %%
import pandas as pd

# %%
data = pd.read_csv("./telco_customer_churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data[data['gender'] == 'Male']
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7041  8361-LTMKD   Male              1     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
data[:6]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# ...

# %%
data[['SeniorCitizen', 'Partner', 'Dependents', 'InternetService']]
# Out:
#       SeniorCitizen Partner Dependents InternetService
# 0                 0     Yes         No             DSL
# 1                 0      No         No             DSL
# 2                 0      No         No             DSL
# 3                 0      No         No             DSL
# 4                 0      No         No     Fiber optic
# ...             ...     ...        ...             ...
# 7038              0     Yes        Yes             DSL
# 7039              0     Yes        Yes     Fiber optic
# 7040              0     Yes        Yes             DSL
# 7041              1     Yes         No     Fiber optic
# 7042              0      No         No     Fiber optic
#
# [7043 rows x 4 columns]

# %%
idx = pd.IndexSlice
data.loc[idx[:25], idx[:'tenure']]
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure
# 0   7590-VHVEG  Female              0     Yes         No       1
# 1   5575-GNVDE    Male              0      No         No      34
# 2   3668-QPYBK    Male              0      No         No       2
# 3   7795-CFOCW    Male              0      No         No      45
# 4   9237-HQITU  Female              0      No         No       2
# 5   9305-CDSKC  Female              0      No         No       8
# 6   1452-KIOVK    Male              0      No        Yes      22
# 7   6713-OKOMC  Female              0      No         No      10
# 8   7892-POOKP  Female              0     Yes         No      28
# 9   6388-TABGU    Male              0      No        Yes      62
# 10  9763-GRSKD    Male              0     Yes        Yes      13
# 11  7469-LKBCI    Male              0      No         No      16
# 12  8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
data.loc[(:250), ('PaymentMethod':'TotalCharges')]
# Out:
#   File "<ipython-input-23-e72c6c55d44a>", line 1
#     data.loc[(:250), ('PaymentMethod':'TotalCharges')]
#               ^
# SyntaxError: invalid syntax

# %%
df1 = pd.read_csv("./20190928-items.csv")
df1
# Out:
#            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# ..          ...       ...                                                ...
# 787  B07WFJ6HRF     Apple  Apple iPhone XS, 512GB, Gold - For Verizon (Re...
# 788  B07WKSVF6X   Samsung  Samsung Galaxy A50 128GB, 4GB RAM 6.4" Display...
# 789  B07WVRJQ7V   Samsung  Samsung Galaxy S9 (64GB, 4GB RAM) 5.8" QHD+ Di...
# 790  B07WXKWDT2  Motorola  Motorola Moto G7 Play (32GB, 2GB RAM) 5.7" HD+...
# 791  B07X51T2VK    HUAWEI  Honor 5X Unlocked Smartphone, 16GB Dark Grey (...
#
# ...

# %%
df2 = pd.read_csv("./20190928-reviews.csv")
df2
# Out:
#              asin             name  rating                date  verified  \
# 0      B0000SX2UC            Janet       3    October 11, 2005     False
# 1      B0000SX2UC       Luke Wyatt       1     January 7, 2004     False
# 2      B0000SX2UC           Brooke       5   December 30, 2003     False
# 3      B0000SX2UC    amy m. teague       3      March 18, 2004     False
# 4      B0000SX2UC    tristazbimmer       4     August 28, 2005     False
# ...           ...              ...     ...                 ...       ...
# 82810  B07WXKWDT2      Prabhakaran       5  September 24, 2019      True
# 82811  B07WXKWDT2         rvwonder       3  September 17, 2019     False
# 82812  B07WXKWDT2         markw707       1   September 8, 2019     False
# 82813  B07WXKWDT2  Amazon Customer       1  September 13, 2019     False
# 82814  B07X51T2VK         Steve H.       4  September 16, 2019      True
#
#                                                    title  \
# ...

# %%
df3 = pd.merge(df2, df1, how='outer')
df3
# Out:
#              asin           name  rating               date verified  \
# 0      B0000SX2UC          Janet     3.0   October 11, 2005    False
# 1      B0000SX2UC     Luke Wyatt     1.0    January 7, 2004    False
# 2      B0000SX2UC         Brooke     5.0  December 30, 2003    False
# 3      B0000SX2UC  amy m. teague     3.0     March 18, 2004    False
# 4      B0000SX2UC  tristazbimmer     4.0    August 28, 2005    False
# ...           ...            ...     ...                ...      ...
# 83602  B07WFJ6HRF            NaN     3.7                NaN      NaN
# 83603  B07WKSVF6X            NaN     4.7                NaN      NaN
# 83604  B07WVRJQ7V            NaN     2.0                NaN      NaN
# 83605  B07WXKWDT2            NaN     3.0                NaN      NaN
# 83606  B07X51T2VK            NaN     4.0                NaN      NaN
#
#                                                    title  \
# 0                            Def not best, but not worst
# ...

# %%
df4 = pd.merge(df2, df1, on="asin")

# %%
pd.concat([df2,df1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#            asin                                               body     brand  \
# 0    B0000SX2UC  I had the Samsung A600 for awhile which is abs...       NaN
# 1    B0000SX2UC  Due to a software issue between Nokia and Spri...       NaN
# 2    B0000SX2UC  This is a great, reliable phone. I also purcha...       NaN
# 3    B0000SX2UC  I love the phone and all, because I really did...       NaN
# 4    B0000SX2UC  The phone has been great for every purpose it ...       NaN
# ..          ...                                                ...       ...
# ...

# %%
df2.append(df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#            asin                                               body     brand  \
# 0    B0000SX2UC  I had the Samsung A600 for awhile which is abs...       NaN
# 1    B0000SX2UC  Due to a software issue between Nokia and Spri...       NaN
# 2    B0000SX2UC  This is a great, reliable phone. I also purcha...       NaN
# 3    B0000SX2UC  I love the phone and all, because I really did...       NaN
# 4    B0000SX2UC  The phone has been great for every purpose it ...       NaN
# ..          ...                                                ...       ...
# 787  B07WFJ6HRF                                                NaN     Apple
# ...
